# %%
import csv
import pandas as pd
m=pd.read_csv(r"C:\Users\Admin\Downloads\data\raw_data.csv")
pd.DataFrame(m)
# Out:
#              Date  MMWR_week Location  Distributed  Distributed_Janssen  \
# 0      10/30/2021         43       TX     44779195              2217800
# 1      10/30/2021         43       NJ     15160695               746500
# 2      12/27/2020         53       PA       291825                    0
# 3      12/27/2020         53       AK        45250                    0
# 4      12/16/2020         51       WI        49725                    0
# ...           ...        ...      ...          ...                  ...
# 38483  12/13/2020         51       AS         3900                    0
# 38484  12/13/2020         51       VI          975                    0
# 38485  12/13/2020         51       MP         4875                    0
# 38486  12/13/2020         51       US        13650                    0
# 38487  12/13/2020         51       GU         3900                    0
#
#        Distributed_Moderna  Distributed_Pfizer  Distributed_Novavax  \
# ...

# %%
#display
m.head()
m.info()
m.describe()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 38488 entries, 0 to 38487
# Columns: 109 entries, Date to Bivalent_Booster_65Plus_Pop_Pct
# dtypes: float64(65), int64(42), object(2)
# memory usage: 32.0+ MB
#           MMWR_week   Distributed  Distributed_Janssen  Distributed_Moderna  \
# count  38488.000000  3.848800e+04         3.848800e+04         3.848800e+04
# mean      23.434447  1.543719e+07         6.895489e+05         5.803219e+06
# std       15.406757  6.751604e+07         2.981533e+06         2.533753e+07
# min        1.000000  0.000000e+00         0.000000e+00         0.000000e+00
# 25%       10.000000  9.751162e+05         2.350000e+04         2.433700e+05
# 50%       20.000000  3.837018e+06         1.724000e+05         1.501160e+06
# 75%       36.000000  1.004543e+07         4.578000e+05         3.962520e+06
# max       53.000000  9.844443e+08         3.249690e+07         3.522477e+08
#
#        Distributed_Pfizer  Distributed_Novavax  Distributed_Unk_Manuf  \
# ...

# %%
# Check for null values
print('Null values in each column:')
print(m.isnull().sum())

# Check for duplicate rows
print('\nNumber of duplicate rows:')
print(m.duplicated().sum())

# Check for inconsistent data types
print('\nData types of each column:')
print(m.dtypes)
# Out:
# Null values in each column:
# Date                                   0
# MMWR_week                              0
# Location                               0
# Distributed                            0
# Distributed_Janssen                    0
#                                    ...
# Bivalent_Booster_12Plus_Pop_Pct    36504
# Bivalent_Booster_18Plus            36504
# Bivalent_Booster_18Plus_Pop_Pct    36504
# Bivalent_Booster_65Plus            36504
# Bivalent_Booster_65Plus_Pop_Pct    36504
# Length: 109, dtype: int64
#
# Number of duplicate rows:
# 0
#
# Data types of each column:
# Date                                object
# MMWR_week                            int64
# Location                            object
# Distributed                          int64
# Distributed_Janssen                  int64
#                                     ...
# Bivalent_Booster_12Plus_Pop_Pct    float64
# Bivalent_Booster_18Plus            float64
# Bivalent_Booster_18Plus_Pop_Pct    float64
# ...

# %% [markdown]
# ## Data Quality Issues in the Dataset
#
#
#
# 1. **Null or Missing Values**
#
#    - These occur when some entries in the dataset are empty or not recorded. Missing values can affect analysis and model performance. It's important to check for nulls and decide whether to fill, drop, or otherwise handle them.
#
#
#
# 2. **Duplicate Rows**
#
#    - Duplicate records arise from repeated data entry or merging datasets. Duplicates can bias results and should be identified and removed if not intentional.
#
#
#
# 3. **Inconsistent Data Types**
#
#    - this occurs when columns may have mixed types (e.g., numbers stored as strings, or dates as text). This can cause errors in analysis and should be standardized (e.g., converting all dates to datetime objects).

# %%
#merge datasets
data1=pd.read_csv(r"C:\Users\Admin\Downloads\data\raw_data.csv")
data2=pd.read_csv(r"C:\Users\Admin\Downloads\data\raw_data.csv")
merged_data=pd.concat([data1,data2],ignore_index=True)
pd.DataFrame(merged_data)
# Out:
#              Date  MMWR_week Location  Distributed  Distributed_Janssen  \
# 0      10/30/2021         43       TX     44779195              2217800
# 1      10/30/2021         43       NJ     15160695               746500
# 2      12/27/2020         53       PA       291825                    0
# 3      12/27/2020         53       AK        45250                    0
# 4      12/16/2020         51       WI        49725                    0
# ...           ...        ...      ...          ...                  ...
# 76971  12/13/2020         51       AS         3900                    0
# 76972  12/13/2020         51       VI          975                    0
# 76973  12/13/2020         51       MP         4875                    0
# 76974  12/13/2020         51       US        13650                    0
# 76975  12/13/2020         51       GU         3900                    0
#
#        Distributed_Moderna  Distributed_Pfizer  Distributed_Novavax  \
# ...
